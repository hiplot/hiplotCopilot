# %%
from pipeline.preprocess import hiplot_preprocess_pipeline

# %%
hiplot_preprocess_pipeline("把data/thing.xlsx中值为风化和无风化的数据转化为数字").get()[0]
# Out:
# 'data/tmp/thing_discrete_mapping_8380f812-a986-4801-84e7-c92aad71eab4.xlsx'

# %%
hiplot_preprocess_pipeline("帮我把data/thing.xlsx文件中名为颜色的列映射成数字").get()[0]
# Out:
# 'data/tmp/thing_discrete_mapping_708acd55-d236-4616-abe1-7f2c18156c46.xlsx'

# %%
hiplot_preprocess_pipeline("将data/thing.xlsx中的非数字类型转化为数字").get()[0]
# Out:
# 'data/tmp/thing_discrete_mapping_14c9ae60-3e76-4792-a501-2dee727627db.xlsx'

# %%
hiplot_preprocess_pipeline("给data/iris.xlsx文件中的缺失值填充为0").get()[0]
# Out:
# 'The missing values in the "data/iris.xlsx" file have been filled with zeros. Here is the updated file: "data/tmp/iris_missing_padding_f1337739-9f2a-4453-8f3b-4fda5a3e4d8d.xlsx". How else can I assist you?'

# %%
hiplot_preprocess_pipeline("帮我把data/iris.xlsx数据中sepal_width列的缺失值填充为平均值").get()[0]
# Out:
# '你可以在这里下载填充了平均值的文件：[iris_missing_padding_878eebf3-c2df-41a8-85fd-3ed5f7f71da1.xlsx](sandbox:/data/tmp/iris_missing_padding_878eebf3-c2df-41a8-85fd-3ed5f7f71da1.xlsx)'
